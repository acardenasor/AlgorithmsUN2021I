# %% [markdown]
# [Link](http://acardenaso.pythonanywhere.com/) a la pagina web

# %% [markdown]
# Integrantes:
#
# Gabriela Maria Garcia Romero
#
# Diego Alejandro Carvajal Beltran
#
# Angela Maria Cardenas Orjuela

# %% [markdown]
# ![LAB5.JPG](data:image/jpeg;base64,...)
